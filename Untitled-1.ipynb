# %%
path1 = r"C:\Users\vaibh\Downloads\Samco_10062025152511_Excel.xlsx"
path2 = r"C:\Users\vaibh\Downloads\ICICI_08052025122000_SSD_2082.xlsx"
path3 = r"C:\Users\vaibh\Downloads\HSBC_06062025122011_HSBCMutualFund.xlsx"

# %%
import pandas as pd
df1 = pd.read_excel(path1)
df2 = pd.read_excel(path2)
df3 = pd.read_excel(path3)

# %%
df1.tail(10)
# Out:
#                 Unnamed: 0                        Unnamed: 1  \
# 52                      51  Max Switch Units (if applicable)
# 53                      52     Swing Pricing (if applicable)
# 54                      53    Side-pocketing (if applicable)
# 55  SIP SWP & STP Details:                               NaN
# 56                      54                         Frequency
# 57                      55                    Minimum amount
# 58                      56                    In multiple of
# 59                      57               Minimum Instalments
# 60                      58                             Dates
# 61                      59           Maximum Amount (if any)
#
#                                            Unnamed: 2
# 52                                     Not Applicable
# 53                                     Not Applicable
# 54                                                Yes
# 55                                                NaN
# ...

# %%
df2.tail(10)
# Out:
#    Fields  SCHEME SUMMARY DOCUMENT  \
# 78     51      Minimum instalments
# 79     52                    Dates
# 80     53  Maximum Amount (If any)
# 81   SWP                       NaN
# 82     48                Frequency
# 83     49           Minimum amount
# 84     50           In multiple of
# 85     51      Minimum instalments
# 86     52                    Dates
# 87     53  Maximum Amount (If any)
#
#                                            Unnamed: 2
# 78  Daily,Weekly,Monthly,Fortnightly = 6\nQuarterl...
# 79  Daily = Daily (only business days)\nWeekly = A...
# 80                                                NaN
# 81                                                NaN
# 82              Monthly,Quarterly, Half Yearly,Annual
# 83                                         Any amount
# 84                                            Re. 1/-
# 85          Monthly,Quarterly, Half Yearly,Annual = 2
# 86  Monthly = Any day*\nQuarterly= Any day*\nHalf ...
# ...

# %%
df3.tail(10)
# Out:
#     Fields                         SCHEME SUMMARY DOCUMENT  \
# 43      44                               Max Switch Amount
# 44      45                Max Switch Units (if applicable)
# 45      46                   Swing Pricing (if applicable)
# 46      47                  Side-pocketing (if applicable)
# 47      48                SIP SWP & STP Details: Frequency
# 48      49           SIP SWP & STP Details: Minimum amount
# 49      50           SIP SWP & STP Details: In multiple of
# 50      51      SIP SWP & STP Details: Minimum Instalments
# 51      52                    SIP SWP & STP Details: Dates
# 52      53  SIP SWP & STP Details: Maximum Amount (if any)
#
#                                            Unnamed: 2
# 43                                                NaN
# 44                                                NaN
# 45                                                 No
# 46  Yes.(Definition of Credit Event is modified as...
# ...
